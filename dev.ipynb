# %%
import sys
sys.path.append('../src' )
sys.path.append('../src/agents' )
sys.path.append('../src/envs' )
sys.path.append('../src/utils' )
sys.path.append('../src/cloud_training' )

import numpy as np
import gym
from PIL import Image
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

def showim(buffer):
    fig, ax = plt.subplots(figsize=(9, 9))
    ax.imshow(buffer,interpolation='nearest',aspect='auto')

# %%
from four_in_a_row_env import FourInARowEnv
from four_dqn_agent import DQNAgent
from simulation import Experiment
import helper
# Out:
# Using TensorFlow backend.

# %%
import training

# %%
trainer = training.Trainer()

# %%
trainer.training()
# Out:
# =================================================
# round : 0
# prepare npc
# preparing agent
# agent with button player is loading model
# Model file not exist
# New model file will be created while learn
# Save model at trial round 0 episode : 0
# Saved model to disk : ../trained_models/four_a_row/NN_128x16
# Update target model at trial round 0 episode : 0
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# freq: 1
# 1
# Save model at trial round 0 episode : 19
# Saved model to disk : ../trained_models/four_a_row/NN_128x16

# %%
interactive = True
# %matplotlib nbagg

num_round = 1
number_of_episodes=10
display_frequency=1

for r in range(num_round):
    print('=================================================')
    print('round : ' + str(r))
    print('prepare npc')
    
    #npc_agent = DQNAgent( who='npc', model_name='NN_128x16', continue_model=True)
    npc_agent = None ### random response agent inside the env  
    
    print('preparing agent')
    agent = DQNAgent( who='player' , model_name=None, load_model=True, save_learnt_to_file=True)
    
    env = FourInARowEnv(npc_agent=npc_agent)
    experiment = Experiment(env, agent, debug_print_interval=200)
    #agent.epsilon = 0
    #experiment.run_agent( max_number_of_episodes=1, max_number_of_steps=100, interactive = True, display_frequency=10)#
    experiment.run_qlearning( max_number_of_episodes=number_of_episodes,  interactive = False, display_frequency=display_frequency)
# Out:
# =================================================
# round : 0
# prepare npc
# preparing agent
# agent with button player is loading model
# Loaded model from disk : ../trained_models/four_a_row/NN_128x16
# <img src="data:image/png;base64,..." width="720">
# episode : 0
# Saved model to disk : ../trained_models/four_a_row/NN_128x16
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="720">

# %%
import os, csv
path = './trained_models/four_a_rowscore.csv'
score = 0.3
print('kkdkdk')
print(path)
if not os.path.exists(path):
    print('ddd')
    with open(path, "w"):
        pass

print('jjjjjjjjjjjjj')
scores_file = open(path, "a")
with scores_file:
    print('kslfjsldkfjj')
    print(path)
    print(scores_file)
    print(score)
    writer = csv.writer(scores_file)
    writer.writerow([score])
# Out:
# kkdkdk
# ./trained_models/four_a_rowscore.csv
# jjjjjjjjjjjjj
# kslfjsldkfjj
# ./trained_models/four_a_rowscore.csv
# <_io.TextIOWrapper name='./trained_models/four_a_rowscore.csv' mode='a' encoding='cp1252'>
# 0.3

# %%
os.path.exists(path)
# Out:
# True

# %%
scores_file = open(path, "a")

# %%
scores_file
# Out:
# <_io.TextIOWrapper name='./trained_models/four_a_rowscore.csv' mode='a' encoding='cp1252'>

# %%
writer = csv.writer(scores_file)

# %%
writer.writerow([score])
# Out:
# 5

# %%
writer.writerow([score])
# Out:
# 5

# %%
import csv 
with open('C:/Users/ray/Documents/repo/four-in-a-row-ai/some.csv', 'a', newline='') as f:
    writer = csv.writer(f)
    writer.writerow([3,2] )

# %%
import csv 
with open('C:/Users/ray/Documents/repo/four-in-a-row-ai/some.csv', 'r') as f:
    reader = csv.reader(f)
    data = list(reader)
    
    data

# %%
data
# Out:
# [['3', '2'], ['3', '2']]

# %%
f.close()

# %%
import sys,os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ray\\Documents\\repo\\four-in-a-row-ai\\notebook'

# %%
a3 = np.random.randint( 0,10, (1,6))

# %%
a1
# Out:
# array([[9, 2, 8, 2, 0, 7]])

# %%
a2
# Out:
# array([[8, 9, 4, 0, 9, 9]])

# %%
a3
# Out:
# array([[2, 1, 0, 5, 5, 7]])

# %%
np.concatenate( [a1,a2,a3])
# Out:
# array([[9, 2, 8, 2, 0, 7],
#        [8, 9, 4, 0, 9, 9],
#        [2, 1, 0, 5, 5, 7]])
