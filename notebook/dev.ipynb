# %%
import sys
sys.path.append('../src' )
sys.path.append('../src/agents' )
sys.path.append('../src/envs' )
sys.path.append('../src/utils' )
sys.path.append('../src/cloud_training' )

import numpy as np
import gym
from PIL import Image
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

def showim(buffer):
    fig, ax = plt.subplots(figsize=(9, 9))
    ax.imshow(buffer,interpolation='nearest',aspect='auto')

# %%
from four_in_a_row_env import FourInARowEnv
from four_dqn_agent import DQNAgent
from simulation import Experiment
import helper
# Out:
# Using TensorFlow backend.

# %%
import training

# %%
trainer = training.Trainer()

# %%
trainer.training()
# Out:
# =================================================
# round : 0
# prepare npc
# preparing agent
# agent with button player is loading model
# Loaded model from disk : ../trained_models/four_a_row/NN_128x16
# Save model at trial round 0 episode : 0
# Saved model to disk : ../trained_models/four_a_row/NN_128x16
# Update target model at trial round 0 episode : 0
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 1
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 2
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 3
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 4
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 5
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 6
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 7
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 8
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 9
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 10
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 11
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 12
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 13
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 14
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 15
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 16
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 17
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 18
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# target model value
# Update target model at trial round 0 episode : 19
# Save model at trial round 0 episode : 19
# Saved model to disk : ../trained_models/four_a_row/NN_128x16

# %%
interactive = True
# %matplotlib nbagg

num_round = 1
number_of_episodes=10
display_frequency=1

for r in range(num_round):
    print('=================================================')
    print('round : ' + str(r))
    print('prepare npc')
    
    #npc_agent = DQNAgent( who='npc', model_name='NN_128x16', continue_model=True)
    npc_agent = None ### random response agent inside the env  
    
    print('preparing agent')
    agent = DQNAgent( who='player' , model_name=None, load_model=True, save_learnt_to_file=True)
    
    env = FourInARowEnv(npc_agent=npc_agent)
    experiment = Experiment(env, agent, debug_print_interval=200)
    #agent.epsilon = 0
    #experiment.run_agent( max_number_of_episodes=1, max_number_of_steps=100, interactive = True, display_frequency=10)#
    experiment.run_qlearning( max_number_of_episodes=number_of_episodes,  interactive = False, display_frequency=display_frequency)
# Out:
# =================================================
# round : 0
# prepare npc
# preparing agent
# agent with button player is loading model
# Loaded model from disk : ../trained_models/four_a_row/NN_128x16
# <img src="data:image/png;base64,..." width="720">
# episode : 0
# Saved model to disk : ../trained_models/four_a_row/NN_128x16
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="720">
