# %%
import sys
sys.path.append('..' )
sys.path.append('../four_ai' )
sys.path.append('../four_ai/manual_game' )
#sys.path.append('../four_ai/agents' )
#sys.path.append('../four_ai/envs' )
#sys.path.append('../four_ai/utils' )
#sys.path.append('../four_ai/cloud_training' )

import numpy as np
import gym
from PIL import Image
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

def showim(buffer):
    fig, ax = plt.subplots(figsize=(9, 9))
    ax.imshow(buffer,interpolation='nearest',aspect='auto')

# %%
import ai
# Out:
# Using TensorFlow backend.

# %%
ai.play()
# Out:
# <img src="data:image/png;base64,..." width="648">
# select column 0-6 , or 'q'
# 1
# Finish : False
# select column 0-6 , or 'q'
# 3
# Finish : False
# select column 0-6 , or 'q'
# 2
# Finish : False
# select column 0-6 , or 'q'
# 0
# Finish : True
# select column 0-6 , or 'q'
# q
